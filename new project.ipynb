# %%
import pandas as pd

# %%
df = pd.read_csv('./kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms
# 0      7129300520  20141013T000000  221900.0         3       1.00  \
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade
# 0             1180      5650     1.0           0     0  ...      7  \
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000  \
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000  \
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df = df.drop('date',axis=1)

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109  \
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
df1 = sc.fit_transform(df)

# %%
new_df = pd.DataFrame(df1,columns=df.columns)

# %%
new_df
# Out:
#              id     price  bedrooms  bathrooms  sqft_living  sqft_lot
# 0      0.886146 -0.866717 -0.398737  -1.447464    -0.979835 -0.228321  \
# 1      0.637511 -0.005688 -0.398737   0.175607     0.533634 -0.189885
# 2      0.365444 -0.980849 -1.473959  -1.447464    -1.426254 -0.123298
# 3     -0.727656  0.174090  0.676485   1.149449    -0.130550 -0.244014
# 4     -0.912881 -0.081958 -0.398737  -0.149007    -0.435422 -0.169653
# ...         ...       ...       ...        ...          ...       ...
# 21608 -1.500888 -0.490545 -0.398737   0.500221    -0.598746 -0.337424
# 21609  0.702159 -0.381588  0.676485   0.500221     0.250539 -0.224386
# 21610 -1.062751 -0.375865 -1.473959  -1.772078    -1.154047 -0.332137
# 21611 -1.491046 -0.381588 -0.398737   0.500221    -0.522528 -0.307076
# 21612 -1.062751 -0.585882 -1.473959  -1.772078    -1.154047 -0.338752
#
#          floors  waterfront      view  condition     grade  sqft_above
# ...

# %%
y = df['price']
x = df.drop(columns=['id','price'])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=44)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((15129, 18), (6484, 18), (15129,), (6484,))

# %% [markdown]
# # Creating a Linear Model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test['Predicted'] = model.predict(x_test)

# %%
y_test
# Out:
# 19175                                                 430000.0
# 15315                                                 275000.0
# 9952                                                  453500.0
# 13235                                                1651000.0
# 19703                                                 319900.0
#                                    ...
# 19431                                                 565000.0
# 3619                                                  122000.0
# 12257                                                 489950.0
# 5122                                                  210000.0
# Predicted    [436534.18797734287, 365228.4044079813, 532882...
# Name: price, Length: 6485, dtype: object

# %%
from sklearn.metrics import r2_score

# %%
model.score(x_train,y_train)
# Out:
# 0.7010817375724038

# %%
model.predict([[2570,1530,543,4456,7747,8889,4321,6548,9087,6644,5671,9087,3451,5678,3256,7890,7654,2137]])
# Out:
# C:\Users\periz\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6.74157792e+09])
